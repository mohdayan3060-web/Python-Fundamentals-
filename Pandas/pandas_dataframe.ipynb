# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# Out:
# hello worlds

# %% [markdown]
# LEARNING PANDAS DATAFRAME

# %%
# tabular data  is dataframe (2d staructre data consistent rows and columns )
# each rows / colums  are series 

#data frame using list(2d list )

student_data=[
    [100,80,40],
    [34,60,21],
    [50,50,50]    
]
student = pd.DataFrame(student_data,columns=['iq','marks','package'])

# %%
#data frame using dictionaries 
student_dict={
    'Iq':[100,60,40],
    'marks':[90,70,32],
    'package':[100,70,60]
}
pd.DataFrame(student_dict)
# Out:
#     Iq  marks  package
# 0  100     90      100
# 1   60     70       70
# 2   40     32       60

# %%
#using read csv 
movie=pd.read_csv(r'C:\Users\hp\Python fundamentals\Pandas\movies.csv')
Ipl_match=pd.read_csv(r'C:\Users\hp\Python fundamentals\Pandas\ipl-matches.csv')
movie
Ipl_match
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movie.columns
Ipl_match.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
# DataFrame attributes and methods 

#shape 
movie.shape
Ipl_match.shape

#dtype(each columns datatype )
movie.dtypes

#Index 
movie.index

#question attributes vs methods 

# coulmns
movie.columns

#values
Ipl_match.values #2d numpy array 

#head
movie.head(2) 
# tail
movie.tail(2)

#shample (randomly rows )
Ipl_match.sample
# Out:
# <bound method NDFrame.sample of           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# ...

# %%
movie.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
Ipl_match.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
#describe   only numerical values apply 
movie.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull((colums missing value ))
Ipl_match.isnull().sum()
movie.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#dublicate 
movie.duplicated()  #true =dublicated  and false =not dublicated 
movie.duplicated().sum()
# Out:
# np.int64(0)

# %%
#rename (replace columns name ),inplace is used to make chnages in original arrray
    
student.rename(columns={'package':'LPA'},inplace=True)
student
# Out:
#     iq  marks  LPA
# 0  100     80   40
# 1   34     60   21
# 2   50     50   50

# %%
#math Methods 
movie.sum(axis=0)

movie.mean(numeric_only=True)
# Out:
# is_adult              0.000000
# year_of_release    2010.263966
# imdb_rating           5.557459
# imdb_votes         5384.263352
# dtype: float64

# %%
#selcting colns 

#fetching single coln
movie['title_x']

Ipl_match['Venue']

#fetching multiple colns 

movie.columns

type(movie[['title_x', 'imdb_id', 'poster_path']])
# Out:
# pandas.DataFrame

# %%
#Selecting rows 

#iloc (searches using index postion(absolute 0,1,2,3,4.......... ) )
movie.iloc[0:5] #last postion is excluded 

movie.iloc[[0,3,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 3           Why Cheat India  tt8108208
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 3           Why Cheat India           Why Cheat India         0
# ...

# %%
# #loc (indexing throw labels ) you need to provide labels 
# movie.loc['key name '] and last postion is  included

# %%
#fetching rows and colns
    
movie.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
#filtering data 
Ipl_match.head(2)

#find all final winers 
Ipl_match.columns
new_df=Ipl_match[Ipl_match['MatchNumber']=='Final']
new_df[['Season','WinningTeam']]
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#find out how many super over is occured 
Ipl_match[Ipl_match['SuperOver'] =='Y'].shape[0]
# Out:
# 14

# %%
#how many match csk win in kolkata 
# & use with binary 
Ipl_match[(Ipl_match['City']=='Kolkata')&(Ipl_match['WinningTeam']=='Chennai Super Kings')].shape[0]

# Ipl_match[Ipl_match['Venue']=='Eden Gardens']
# Out:
# 5

# %% [markdown]
# #toss winner is match winner  in percentage
# (Ipl_match[Ipl_match['TossWinner'] == Ipl_match['WinningTeam']].shape[0]/Ipl_match.shape[0])*100

# %%
# imbd_rating higer then 8 and voters >10000
movie[(movie['imdb_rating'] >8) &(movie['imdb_votes']>10000)].shape[0]
# Out:
# 43

# %%
movie[movie['genres']=='Action']
# Out:
#                                title_x     imdb_id  \
# 78                           Dabangg 3   tt7059844
# 176                       Aa Gaya Hero   tt5896934
# 367                     Gabbar Is Back   tt2424988
# 368                     Gabbar Is Back   tt2424988
# 435                        Sorry Daddy   tt4994210
# 452                           Ranbanka   tt5151622
# 535                        Desi Kattey   tt3877652
# 538                  Spark (2014 film)   tt3893476
# 637             Boss (2013 Hindi film)   tt2571140
# 1146                Adharm (2006 film)   tt2435680
# 1171  Dharti Kahe Pukar Ke (2006 film)   tt5216486
# 1310                        Vidyaarthi   tt1483815
# 1411               Aaj Ka Andha Kanoon   tt0426863
# 1585                    Bhairav (film)   tt0466208
# 1627                             Daaka  tt10833860
#
#                                             poster_path  \
# 78    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# Adding new colns 
#completly New

movie['Country']='India'
movie
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#dropping all missing values 
movie.info()
# movie.dropna(inplace=True)
movie.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
#important  dataFrrame function 
#astype
Ipl_match.info()
Ipl_match['ID']=Ipl_match['ID'].astype('int32')
Ipl_match
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...
